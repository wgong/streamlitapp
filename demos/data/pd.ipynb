# %%
import numpy as np
import pandas as pd

# %%
data = np.random.randn(20, 3)

# %%
data
# Out:
# array([[-0.32518718, -0.36118458, -0.63147512],
#        [-0.40266286,  0.13078796,  1.93339715],
#        [-0.25804648, -0.02845898, -1.04964876],
#        [-0.48291893,  0.04433989, -2.25537204],
#        [-1.04074587,  2.20627409,  0.90250899],
#        [ 0.57486885, -0.10501372,  0.67423806],
#        [-0.18966292,  1.67024586,  0.79390223],
#        [ 0.21426854,  0.56054508, -1.63436565],
#        [ 0.01842289,  0.27132932,  1.40669995],
#        [ 0.24317282, -1.3972314 , -0.41669755],
#        [-0.57656048, -0.28328433, -0.34393927],
#        [-0.04566868, -0.45959801,  1.45055419],
#        [ 0.54678304, -0.9566176 , -1.97019213],
#        [ 0.13740114, -0.8771163 , -0.19032063],
#        [-2.00642477, -1.44321564,  0.73991324],
#        [ 1.22976276,  0.61108804,  0.37332194],
#        [ 0.13034924, -1.09729471, -0.66934932],
#        [-0.09835746,  1.48141717,  0.93439463],
#        [-1.40283561, -1.57763714,  2.07437895],
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# if using a jupyter notebook
# %matplotlib inline

# %%
x = np.arange(0,4*np.pi,0.1)

# %%
y = [[np.sin(i), 1.*np.cos(i), 1.5*np.sin(3*i)] for i in x]

# %%
plt.plot(x,y)
plt.show()
